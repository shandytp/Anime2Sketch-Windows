# %% [markdown]
# <a href="https://colab.research.google.com/github/shandytp/Anime2Sketch-Windows/blob/master/Anime2Sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Anime2Sketches Google Colab Version
#
# You can experiment it with this Google Colab. You just run the code cell and upload your image to Google Colab.

# %% [markdown]
# # Install Miniconda on Google Colab
#
# Source : https://towardsdatascience.com/conda-google-colab-75f7c867a522

# %%
# !echo $PYTHONPATH
# Out:
# /env/python

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
import sys
sys.path
# Out:
# ['',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# !ls /usr/local/lib/python3.6/dist-packages

# %%
import sys
_ = (sys.path
        .append("/usr/local/lib/python3.6/site-packages"))

# %%
# !conda create -n a2s python=3.6
# Out:
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.4
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/a2s
#
#   added / updated specs:
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ld_impl_linux-64-2.33.1    |       h53a641e_7         645 KB
#     openssl-1.1.1k             |       h27cfd23_0         3.8 MB
#     zlib-1.2.11                |       h7b6447c_3         120 KB
#     readline-8.1               |       h27cfd23_0         464 KB
#     pip-21.0.1                 |   py36h06a4308_0         2.0 MB
#     ncurses-6.2                |       he6710b0_1         1.1 MB
#     xz-5.2.5                   |       h7b6447c_0         438 KB
# ...

# %%
# !nvidia-smi
# Out:
# Fri May 14 06:04:56 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %%bash
# echo ". /usr/local/etc/profile.d/conda.sh" >> ~/.bashrc
# sudo ln -s /usr/local/etc/profile.d/conda.sh /etc/profile.d/conda.sh

# %%
# !source activate a2s

# %% [markdown]
# # Install Library with Conda

# %%
# !conda install ffmpeg pytorch==1.7.1 torchvision==0.8.2 torchaudio==0.7.2 cudatoolkit=10.2 -c pytorch
# Out:
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.4
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudatoolkit=10.2
#     - ffmpeg
#     - pytorch==1.7.1
#     - torchaudio==0.7.2
#     - torchvision==0.8.2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     mkl_random-1.2.1           |   py38ha9443f7_2         354 KB
#     cudatoolkit-10.2.89        |       hfd86e86_1       540.0 MB
#     ninja-1.10.2               |       hff7bd54_1         1.9 MB
#     torchvision-0.8.2          |       py38_cu102        17.8 MB  pytorch
#     lz4-c-1.9.3                |       h2531618_0         216 KB
#     numpy-1.20.1               |   py38h93e21f0_0          21 KB
# ...

# %% [markdown]
# # Clone the Repository from GitHub

# %%
# !git clone https://github.com/bycloudai/Anime2Sketch-Windows.git
# Out:
# Cloning into 'Anime2Sketch-Windows'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 56 (delta 22), reused 29 (delta 4), pack-reused 0
# Unpacking objects: 100% (56/56), done.

# %% [markdown]
# ### Upload the Weights to the `weights/` directory

# %%
# !ls -lha Anime2Sketch-Windows/weights/
# Out:
# total 208M
# drwxr-xr-x 2 root root 4.0K May 14 06:11  .
# drwxr-xr-x 6 root root 4.0K May 14 06:10  ..
# -rw-r--r-- 1 root root 208M May 14 06:39  netG.pth
# -rw-r--r-- 1 root root    0 May 14 06:10 'Put the weights here'

# %%
# %cd Anime2Sketch-Windows/
# Out:
# /content/Anime2Sketch-Windows

# %% [markdown]
# # Run on a specific image

# %%
# !python test.py --dataroot /content/Anime2Sketch-Windows/test_samples/madoka.jpg --load_size 512 --output_dir /content/Anime2Sketch-Windows/result/

# %% [markdown]
# # Run on a folder

# %%
# !python test.py --dataroot /content/Anime2Sketch-Windows/test_samples/coba2/ --load_size 512 --output_dir /content/Anime2Sketch-Windows/result/

# %% [markdown]
# # Run on a video

# %%
# !ffmpeg -i /content/Anime2Sketch-Windows/test_samples/*YOUR_MP4_NAME*.mp4  -vf fps=*YOUR_FPS_COUNT* /content/Anime2Sketch-Windows/test_samples/*YOUR_MP4_NAME*/%06d.jpg

# %%
# !python test.py --dataroot /content/Anime2Sketch-Windows/test_samples/*FOLDER_NAME* --load_size 512 --output_dir /content/Anime2Sketch-Windows/result/*FOLDER_NAME*

# %%
# !ffmpeg -i /content/Anime2Sketch-Windows/result/*YOUR_MP4_NAME*/%06d.jpg -vf fps=*YOUR_FPS_COUNT* /content/Anime2Sketch-Windows/result/*YOUR_MP4_NAME*
